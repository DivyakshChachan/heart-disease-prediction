# %% [markdown]
# # 02 - Feature Engineering
# Preprocessing pipeline: imputation, scaling, encoding.

# %%
import pandas as pd
import os
from sklearn.model_selection import train_test_split
from src.data_preprocessing import load_dataset, get_feature_lists, build_preprocessor, split_X_y
csv_path = os.path.join('..','data','heart_disease_dataset.csv')
df = load_dataset(csv_path)
numeric, categorical = get_feature_lists(df)
X, y = split_X_y(df)
preprocessor = build_preprocessor(numeric, categorical)
preprocessor
